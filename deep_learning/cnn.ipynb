# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ##### data preprocessing

# %% [markdown]
# > data augmentation to prevent over fitting

# %% [markdown]
# preprocess training set

# %%
train_datagen = ImageDataGenerator(
    rescale = 1/255.0,
    zoom_range = 0.2,
    shear_range = 0.2,
    horizontal_flip = True
)

# %%
training_set = train_datagen.flow_from_directory(
    '../data/cats_dogs/training_set',
    target_size = (64, 64),
    batch_size = 32,
    class_mode = 'binary'
)
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# preprocess test set

# %%
test_datagen = ImageDataGenerator(rescale = 1/255.0)

# %%
test_set = test_datagen.flow_from_directory(
    '../data/cats_dogs/test_set',
    target_size = (64, 64),
    batch_size = 32,
    class_mode = 'binary'
)
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ##### build Convolutional Neural Network

# %% [markdown]
# initialize CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# input

# %%
cnn.add(tf.keras.layers.InputLayer(shape = (64, 64, 3)))

# %% [markdown]
# convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters = 32, kernel_size = 3, activation = 'relu'))

# %% [markdown]
# max pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size = 2, strides = 2))

# %% [markdown]
# convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters = 32, kernel_size = 3, activation = 'relu'))

# %% [markdown]
# max pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size = 2, strides = 2))

# %% [markdown]
# flatten

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# dense layers

# %%
cnn.add(tf.keras.layers.Dense(units = 16, activation = 'relu'))

# %%
cnn.add(tf.keras.layers.Dense(units = 8, activation = 'relu'))

# %% [markdown]
# output layer

# %%
cnn.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# %% [markdown]
# ##### train model

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# training cum evaluation

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 15)
# Out:
# Epoch 1/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 68ms/step - accuracy: 0.5859 - loss: 0.6615 - val_accuracy: 0.6850 - val_loss: 0.5929
# Epoch 2/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 75ms/step - accuracy: 0.6883 - loss: 0.5977 - val_accuracy: 0.6760 - val_loss: 0.6101
# Epoch 3/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 73ms/step - accuracy: 0.7103 - loss: 0.5661 - val_accuracy: 0.7410 - val_loss: 0.5295
# Epoch 4/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 73ms/step - accuracy: 0.7310 - loss: 0.5366 - val_accuracy: 0.7540 - val_loss: 0.5103
# Epoch 5/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 73ms/step - accuracy: 0.7404 - loss: 0.5192 - val_accuracy: 0.7450 - val_loss: 0.5179
# Epoch 6/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.7534 - loss: 0.5037 - val_accuracy: 0.7770 - val_loss: 0.4718
# Epoch 7/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.7688 - loss: 0.4829 - val_accuracy: 0.7820 - val_loss: 0.4743
# Epoch 8/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.7679 - loss: 0.4726 - val_accuracy: 0.7725 - val_loss: 0.4774
# Epoch 9/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.7815 - loss: 0.4577 - val_accuracy: 0.7810 - val_loss: 0.4682
# Epoch 10/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.7960 - loss: 0.4491 - val_accuracy: 0.7840 - val_loss: 0.4653
# Epoch 11/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 76ms/step - accuracy: 0.7989 - loss: 0.4339 - val_accuracy: 0.7430 - val_loss: 0.5260
# Epoch 12/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 76ms/step - accuracy: 0.7933 - loss: 0.4371 - val_accuracy: 0.7990 - val_loss: 0.4368
# Epoch 13/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 76ms/step - accuracy: 0.8048 - loss: 0.4202 - val_accuracy: 0.7835 - val_loss: 0.4727
# Epoch 14/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.7999 - loss: 0.4258 - val_accuracy: 0.8040 - val_loss: 0.4410
# Epoch 15/15
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 74ms/step - accuracy: 0.8064 - loss: 0.4142 - val_accuracy: 0.7890 - val_loss: 0.4589

# %% [markdown]
# #### predict on single input

# %%
from keras.preprocessing import image

test_img = image.load_img('../data/cats_dogs/cat.jpg', target_size = (64, 64))

# %%
test_img = image.img_to_array(test_img)

test_img = test_img / 255.0

test_img = np.expand_dims(test_img, axis = 0) # add batch as the 1st dimension (1, 64, 64, 3)

# %%
training_set.class_indices
# Out:
# {'cats': 0, 'dogs': 1}

# %%
result = cnn.predict(test_img)[0][0] # get the 1st image of 1st batch from the output
print(result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 0.5748906

# %%
if result < 0.5:
    print('cat')

else:
    print('dog')
# Out:
# dog
